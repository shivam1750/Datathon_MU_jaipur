# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Air_Quality.csv")

# %%
data.head()
# Out:
#    Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0     216498           386            Ozone (O3)    Mean          ppb
# 1     216499           386            Ozone (O3)    Mean          ppb
# 2     219969           386            Ozone (O3)    Mean          ppb
# 3     219970           386            Ozone (O3)    Mean          ppb
# 4     164876           383  Sulfur Dioxide (SO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                    Geo Place Name  \
# 0            CD          313               Coney Island (CD13)
# 1            CD          313               Coney Island (CD13)
# 2       Borough            1                             Bronx
# 3       Borough            1                             Bronx
# 4            CD          211  Morris Park and Bronxdale (CD11)
#
#       Time Period  Start_Date  Data Value  Message
# 0     Summer 2013  06/01/2013       34.64      NaN
# 1     Summer 2014  06/01/2014       33.22      NaN
# ...

# %%
data.isna().sum()
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           16122
# dtype: int64

# %%
data.tail(5)
# Out:
#        Unique ID  Indicator ID        Name Measure Measure Info Geo Type Name  \
# 16117     671118           386  Ozone (O3)    Mean          ppb            CD
# 16118     671119           386  Ozone (O3)    Mean          ppb            CD
# 16119     671120           386  Ozone (O3)    Mean          ppb            CD
# 16120     671121           386  Ozone (O3)    Mean          ppb            CD
# 16121     671122           386  Ozone (O3)    Mean          ppb            CD
#
#        Geo Join ID                          Geo Place Name  Time Period  \
# 16117          306    Park Slope and Carroll Gardens (CD6)  Summer 2020
# 16118          305   East New York and Starrett City (CD5)  Summer 2020
# 16119          304                          Bushwick (CD4)  Summer 2020
# 16120          303                Bedford Stuyvesant (CD3)  Summer 2020
# 16121          302  Fort Greene and Brooklyn Heights (CD2)  Summer 2020
#
#        Start_Date  Data Value  Message
# ...

# %%
data.corr()
# Out:
#               Unique ID  Indicator ID  Geo Join ID  Data Value  Message
# Unique ID      1.000000     -0.097728     0.003862   -0.031475      NaN
# Indicator ID  -0.097728      1.000000    -0.038077    0.283966      NaN
# Geo Join ID    0.003862     -0.038077     1.000000   -0.007684      NaN
# Data Value    -0.031475      0.283966    -0.007684    1.000000      NaN
# Message             NaN           NaN          NaN         NaN      NaN

# %%
data.describe()
# Out:
#            Unique ID  Indicator ID   Geo Join ID    Data Value  Message
# count   16122.000000  16122.000000  1.612200e+04  16122.000000      0.0
# mean   339480.955589    427.131063  6.133394e+05     19.129163      NaN
# std    194099.809551    109.657607  7.916715e+06     21.673789      NaN
# min    130355.000000    365.000000  1.000000e+00      0.000000      NaN
# 25%    172183.250000    365.000000  2.020000e+02      8.460000      NaN
# 50%    221882.500000    375.000000  3.030000e+02     13.900000      NaN
# 75%    547749.750000    386.000000  4.040000e+02     25.470000      NaN
# max    671122.000000    661.000000  1.051061e+08    424.700000      NaN

# %%
data.drop('Message',inplace=True , axis=1)

# %%
data
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(),cmap='Blues')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter(data,x='Geo Place Name',y='Geo Type Name')

fig.show()

# %%
px.area(data, x="Geo Type Name", y="Geo Place Name",color=data.index)

# %%
fig = px.histogram(data, x="Geo Type Name", y="Geo Place Name",color=data.index)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-7f6a8417a043> in <module>
# ----> 1 fig = px.histogram(data, x="Geo Type Name", y="Data Value",color=data.index)
#       2 fig.show()
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\express\_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     478     `orientation` is `'h'`).
#     479     """
# --> 480     return make_figure(
# ...
